# %% [markdown]
# <div dir = "rtl">
#
# # **بسم الله الرحمن الرحیم**
#
# </div>

# %% [markdown]
# <h2 style="direction: rtl; text-align: right;">مقدمه</h2>
#
# <p style="direction: rtl; text-align: right;">
# در این کتاب دیجیتال که اکنون در صفحهٔ گیت مشاهده می‌کنید، تلاش شده است تا برخی از مثال‌ها و تمرین‌های کتاب
# <em>جبر خطی</em>
# استاد <strong>دکتر سعیدی</strong> با استفاده از زبان برنامه‌نویسی پایتون پیاده‌سازی و بررسی شوند.
# هدف از این کار، ایجاد پلی میان ریاضیات نظری و پیاده‌سازی عملی آن در کامپیوتر است؛ پلی که به شما کمک می‌کند مفاهیم جبر خطی را نه فقط از نگاه ریاضیاتی، بلکه از زاویهٔ دید الگوریتمی و محاسباتی نیز درک کنید.
# </p>
#
# <p style="direction: rtl; text-align: right;">
# قبل از آنکه وارد کدنویسی و حل مسائل شویم، لازم دانستم اندکی دربارهٔ نگاه کامپیوتر به مفاهیمی مانند ماتریس‌ها صحبت کنیم؛
# چرا که بخش زیادی از آنچه در ادامه خواهد آمد، بر پایهٔ همین درک صحیح استوار است.
# وقتی با پایتون کار می‌کنیم، در واقع داریم با ساختارهایی سر و کار داریم که نحوهٔ ذخیره‌سازی، نمایش و پردازش داده‌ها را در کامپیوتر تعیین می‌کنند.
# پس اگر می‌خواهیم در ادامه کدها را بهتر بفهمیم و الگوریتم‌های خودمان را با اطمینان بیشتری پیاده‌سازی کنیم، لازم است کمی از دنیای صرفاً ریاضی فاصله بگیریم و دیدی رایانشی‌تر به موضوعات داشته باشیم.
# </p>
#
# <h3 style="direction: rtl; text-align: right;">نکتهٔ مهم قبل از شروع</h3>
#
# <p style="direction: rtl; text-align: right;">
# بهتر است پیش از مطالعهٔ این بخش‌ها، آشنایی اولیه‌ای با زبان برنامه‌نویسی <strong>پایتون</strong> داشته باشید.
# هدف ما در این کتاب، آموزش کامل پایتون نیست؛ بلکه می‌خواهیم <strong>مفاهیم جبر خطی</strong> را با کمک پایتون پیاده‌سازی کنیم تا آن‌ها را بهتر درک کنیم و در عمل نیز به‌کار ببریم.
# </p>
#
# <p style="direction: rtl; text-align: right;">
# اگر بخواهیم تمام مباحث زبان پایتون را از صفر توضیح دهیم باعث می‌شود که هم از مسیر اصلی‌مان (یعنی حل مثال و تمرین جبر خطی) دور شویم و هم حجم مطالب بسیار زیاد شود که ممکن است باعث خستگی و سردرگمی شما عزیزان شود.
# </p>
#
# <p style="direction: rtl; text-align:right;">
# پس فرض ما این است که شما با مقدمات پایتون مثل:
# </p>
#
# <ul style="direction: rtl; text-align: right;">
#   <li>متغیرها</li>
#   <li>لیست‌ها</li>
#   <li>توابع</li>
#   <li>اندیس‌گذاری</li>
#   <li>و اجرای کد در Jupyter Notebook</li>
# </ul>
#
# <p style="direction: rtl; text-align:right;">
# تا حدی آشنا هستید.
# اگر هم هنوز مطمئن نیستید، نگران نباشید؛ در مسیر یادگیری، مثال‌های ساده و قدم‌به‌قدم ارائه می‌کنیم تا بتوانید به‌راحتی مباحث را دنبال کنید.
# </p>
#
# <p style="direction: rtl; text-align:right;">
# امیدوارم این مطالب پیش رو مسیر را برای ورود به مباحث جذاب‌تر و عمیق‌تر هموار کند و تجربه‌ای لذت‌بخش و کاربردی از جبر خطی و برنامه‌نویسی پایتون برای شما رقم بزند.
# </p>
#
# <blockquote style="direction: rtl; text-align:right;">
# <strong>محمد سجاد شریفی پناه ✍️</strong>
# </blockquote>
# <hr>

# %% [markdown]
# <h3 style="direction: rtl; text-align: right;">ماتریس در کامپیوتر</h3>
#
# <p style="direction: rtl; text-align: right;">
# ماتریس را از قبل به‌صورت یک جدول روی کاغذ می‌شناسید. مثلاً ماتریس زیر را در نظر بگیرید:
# </p>
#
# <div style=" text-align: center; margin-top: 10px; margin-bottom: 10px;">
#
# $$
# A =
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6
# \end{bmatrix}
# $$
#
# </div>
#
# <p style="direction: rtl; text-align: right;">
# از دید ما این یک ماتریس <span dir="ltr">2×3</span> است؛ دو سطر و سه ستون.
# </p>
#
# <p style="direction: rtl; text-align: right;">
# اما از نگاه کامپیوتر، چنین جدولی باید به‌صورت داده‌های خطی و قابل‌ذخیره‌سازی نمایش داده شود.
# یک راه ساده برای نمایش این ماتریس در پایتون این است که آن را به شکل «لیستِ لیست‌ها» بنویسیم:
# </p>
#
# <p style="
#     direction: rtl;
#     text-align: right;
#     font-family: monospace;
#     background-color: #3a3a3a;
#     color: #e4e4e4;
#     padding: 8px;
#     border-radius: 6px;
# ">
# A = [[1, 2, 3], [4, 5, 6]]
# </p>
#
# <p style="direction: rtl; text-align: right;">
# در این‌جا:
# </p>
#
# <ul style="direction: rtl; text-align: right;">
#   <li>خودِ A یک «لیست» است که <strong>دو عنصر</strong> دارد.</li>
#   <li>هر عنصرِ A خودش یک «لیست» است که <strong>سه عدد</strong> داخلش ذخیره شده است.</li>
#   <li>لیست اول: [3, 2, 1] همان <strong>سطر اول</strong> ماتریس است.</li>
#   <li>لیست دوم: [6, 5, 4] همان <strong>سطر دوم</strong> ماتریس است.</li>
# </ul>
#
# <p style="direction: rtl; text-align: right;">
# به بیان ساده، می‌توانیم بگوییم:
# </p>
#
# <p style="
#     direction: rtl;
#     text-align: right;
#     font-family: monospace;
#     background-color: #3a3a3a;
#     color: #e4e4e4;
#     padding: 8px;
#     border-radius: 6px;
# ">
# کامپیوتر ماتریس ما را این‌گونه می‌بیند:
# A = [[1, 2, 3], [4, 5, 6]]
# </p>
#
# <hr>
#
# <h3 style="direction: rtl; text-align: right;">دسترسی به یک درایهٔ خاص</h3>
#
# <p style="direction: rtl; text-align: right;">
# فرض کنید می‌خواهیم به <strong>درایهٔ سطر اول، ستون سوم</strong> این ماتریس دسترسی پیدا کنیم.
# این همان عدد ۳ است.
# </p>
#
# <p style="direction: rtl; text-align: right;">
# با توجه به ساختار A در پایتون:
# </p>
#
# <ul style="direction: rtl; text-align: right;">
#   <li>ابتدا باید سراغ <strong>سطر اول</strong> برویم -> لیست اول -> [1, 2, 3]</li>
#   <li>سپس از داخل آن، <strong>عنصر سوم</strong> را انتخاب کنیم.</li>
# </ul>
#
# <p style="direction: rtl; text-align: right;">
# کامپیوتر (و پایتون) این کار را با «اندیس‌گذاری» انجام می‌دهد.
# فقط یک نکته مهم:
# </p>
#
# <blockquote style="direction: rtl; text-align: right;">
# در پایتون شمارش از <strong>صفر</strong> شروع می‌شود!
# </blockquote>
#
# <p style="direction: rtl; text-align: right;">
# بنابراین:
# </p>
#
# <ul style="direction: rtl; text-align: right;">
#   <li>سطر اول -> اندیس <code>0</code></li>
#   <li>سطر دوم -> اندیس <code>1</code></li>
# </ul>
#
# <ul style="direction: rtl; text-align: right;">
#   <li>ستون اول -> اندیس <code>0</code></li>
#   <li>ستون دوم -> اندیس <code>1</code></li>
#   <li>ستون سوم -> اندیس <code>2</code></li>
# </ul>
#
# <p style="direction: rtl; text-align: right;">
# پس برای درایهٔ سطر اول، ستون سوم می‌نویسیم:
# </p>
#
# <p style="
#     direction: rtl;
#     text-align: right;
#     font-family: monospace;
#     background-color: #3a3a3a;
#     color: #e4e4e4;
#     padding: 8px;
#     border-radius: 6px;
# ">
# A[0][2]
# </p>
#
# <p style="direction: rtl; text-align: right;">
# به زبان ساده:
# </p>
#
# <blockquote style="direction: rtl; text-align: right;">
# «آقای کامپیوتر! برو داخل لیست A -> عنصر اول را بردار (سطر اول) -> حالا از آن لیست، عنصر سوم را بده به من.»
# <br>
# خروجی این درخواست عدد <strong>۳</strong> خواهد بود.
# </blockquote>

# %%
# لیست ها در پایتون با [] پیاده سازی میشود
A = [
    [1,2,3],
    [4,5,6]
]

# در پایتون اندیس‌ها از 0 شروع می‌شوند.
# سطر اول -> اندیس 0
# سطر دوم -> اندیس 1

# ستون‌ها هم همینطور:
# ستون اول -> اندیس 0
# ستون دوم -> اندیس 1
# ستون سوم -> اندیس 2
# حالا می‌خواهیم درایهٔ سطر اول، ستون سوم را بگیریم.
element = A[0][2]
print(element)
# حالا بیاین ببینیم خود ماتریسمون چطوری نشون داده میشه؟ 
print("A = ", A)
# Out:
# 3
# A =  [[1, 2, 3], [4, 5, 6]]

# %% [markdown]
# <p style="direction: rtl; text-align: right;">
# این نمایش، بیشتر مناسب ذخیره‌سازی است تا نمایش ریاضی.
# اما اگر بخواهیم ماتریس را به شکل منظم و سطر‌به‌سطر مانند چیزی که روی کاغذ می‌بینیم چاپ کنیم، باید خودمان این کار را با استفاده از یک حلقه انجام دهیم.
# </p>
#
# <p style="direction: rtl; text-align: right;">
# برای این کار، ایدهٔ بسیار ساده‌ای داریم:
# </p>
#
# <ol style="direction: rtl; text-align: right;">
#   <li>هر سطر از ماتریس، خودش یک «لیست» است.</li>
#   <li>پس کافی است روی سطرهای ماتریس یک حلقه بزنیم.</li>
#   <li>داخل هر سطر، روی عناصر آن حلقه بزنیم و آن‌ها را کنار هم چاپ کنیم.</li>
#   <li>پس از چاپ هر سطر، به خط بعد برویم.</li>
# </ol>
#
# <p style="direction: rtl; text-align: right;">
# به این ترتیب می‌توانیم ماتریس را دقیقاً به فرمت دلخواه خود نمایش دهیم.
# </p>
#
# <p style="direction: rtl; text-align: right;">
# در ادامه شکل ارتقایافتهٔ چاپ ماتریس را می‌بینید:
# </p>

# %%
for row in A:                 # row هر بار یک لیست است
    for element in row:       # element هر بار یک عدد از آن سطر است
        print(element, end="  ")  # دو فاصله بین عناصر برای زیبایی
    print()                   # رفتن به سطر بعد
# Out:
# 1  2  3
# 4  5  6

# %% [markdown]
# <h3 style="direction: rtl; text-align: right;">چرا از کتابخانه‌هایی مثل NumPy استفاده می‌کنیم؟</h3>
#
# <p style="direction: rtl; text-align: right;">
# در بخش قبل دیدیم که اگر بخواهیم تنها با «پایتون خام» یک ماتریس را نمایش دهیم یا روی آن عملیات انجام دهیم، کار کمی سخت و زمان‌بر می‌شود.
# پایتون به‌صورت پیش‌فرض ساختارهایی مثل «ماتریس» یا «عملیات جبر خطی» را ندارد و برای انجام این کارها باید از لیست‌ها و حلقه‌ها کمک بگیریم.
# </p>
#
# <p style="direction: rtl; text-align: right;">
# برای حل این محدودیت‌ها، در دنیای برنامه‌نویسی علمی از کتابخانه‌هایی استفاده می‌شود که بخش‌های اصلی‌شان در زبان‌های سریع‌تری مثل <strong>C</strong> و <strong>C++</strong> نوشته شده است.
# این کتابخانه‌ها:
# </p>
#
# <ul style="direction: rtl; text-align: right;">
#   <li>توابع آماده و استاندارد برای کار با ماتریس‌ها دارند</li>
#   <li>بسیار سریع‌تر از پایتون خام اجرا می‌شوند</li>
#   <li>حافظه را به‌صورت بهینه مدیریت می‌کنند</li>
#   <li>و استفاده از آن‌ها بسیار ساده‌تر از نوشتن همه‌چیز از صفر است</li>
# </ul>
#
# <p style="direction: rtl; text-align: right;">
# یکی از مهم‌ترین و پرکاربردترین این کتابخانه‌ها، <strong>NumPy</strong> است.
# NumPy یک نوع دادهٔ ویژه به نام <code>ndarray</code> دارد که مخصوص آرایه‌ها و ماتریس‌های چندبعدی طراحی شده است.
# با استفاده از آن می‌توانیم:
# </p>
#
# <ul style="direction: rtl; text-align: right;">
#   <li>ماتریس بسازیم</li>
#   <li>به درایه‌های آن دسترسی پیدا کنیم</li>
#   <li>عملیات جبر خطی را اجرا کنیم</li>
#   <li>و از سرعت بالایی که پشت صحنه توسط کدهای C/C++ فراهم شده، استفاده کنیم</li>
# </ul>
#
# <p style="direction: rtl; text-align: right;">
# به همین دلیل، NumPy یکی از پایه‌های اصلی برنامه‌نویسی علمی در پایتون به شمار می‌آید و ابزار بسیار مناسبی برای یادگیری جبر خطی در محیط کامپیوتری است.
# </p>
#
# <p style="direction: rtl; text-align: right;">
# برای نصب NumPy روی پایتون می‌توانید از دستور زیر در ترمینال استفاده کنید:
# </p>
#
# <p style="
#     direction: rtl;
#     text-align: right;
#     font-family: monospace;
#     background-color: #3a3a3a;
#     color: #e4e4e4;
#     padding: 8px;
#     border-radius: 6px;
# ">
# pip install numpy
# </p>
#
# <p style="direction: rtl; text-align: right;">
# در ادامه ماتریس قبلی‌مان را با NumPy تعریف کرده و مثل قبل به یک درایه از آن دسترسی پیدا می‌کنیم.
# </p>

# %%
import numpy as np  # وارد کردن کتابخانه NumPy

# تعریف ماتریس به‌صورت آرایه‌ی NumPy
# این ماتریس همان بود که قبلاً با لیست‌ها ساخته بودیم
A = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

print("matrix A:")
print(A)

# دسترسی به درایهٔ سطر اول، ستون سوم
# اندیس‌گذاری در NumPy از صفر شروع می‌شود
element = A[0, 2]   # سطر 0، ستون 2

print("\n",element)
# Out:
# matrix A:
# [[1 2 3]
#  [4 5 6]]
#
#  3

# %% [markdown]
# <h3 style="direction: rtl; text-align: right;">چرا تعریف ماتریس در NumPy به‌نظر آشناست؟</h3>
#
# <p style="direction: rtl; text-align: right;">
# اگر دقت کنید، وقتی با NumPy ماتریس تعریف می‌کنیم، شکل کدمان خیلی با حالت پایتون خام متفاوت نیست.
# مثلاً همین کدی که کمی بالاتر نوشتیم:
# </p>
#
# <pre style="
#     direction: ltr;
#     text-align: left;
#     background-color: #3a3a3a;
#     color: #e4e4e4;
#     padding: 8px;
#     border-radius: 6px;
#     font-family: monospace;
#     margin: 0 auto;
# ">
# A = np.array([
#     [1, 2, 3],
#     [4, 5, 6]
# ])
# </pre>
#
# <p style="direction: rtl; text-align: right;">
# تابع <code>array</code> به ما اجازه می‌دهد یک آرایه‌ی چندبعدی (یا همان ماتریس) بسازیم.
# اما سؤال مهم این است: <strong>ورودی این تابع باید چه باشد؟</strong>
# </p>
#
# <p style="direction: rtl; text-align: right;">
# برای ساخت ماتریس، ورودی دقیقاً همان چیزی است که قبلاً توضیح دادیم:
# </p>
#
# <ul style="direction: rtl; text-align: right;">
#   <li>یک لیست اصلی داریم -> <code>[...]</code></li>
#   <li>داخل آن دو لیست دیگر قرار می‌دهیم -> هر کدام یک سطر</li>
#   <li>هر سطر شامل سه عدد است -> ستون‌ها</li>
# </ul>
#
# <p style="direction: rtl; text-align: right;">
# به بیان ساده‌تر:
# </p>
#
# <blockquote style="direction: rtl; text-align: right;">
# ما داریم همان ساختار «لیستِ لیست‌ها» را وارد تابع NumPy می‌کنیم.
# فقط این بار نتیجه‌اش به‌جای اینکه یک لیست معمولی باشد،
# تبدیل به یک <strong>آرایه‌ی قدرتمند NumPy</strong> می‌شود.
# </blockquote>
#
# <hr>
#
# <h3 style="direction: rtl; text-align: right;">تفاوت ماتریس پایتون خام و ماتریس NumPy</h3>
#
# <p style="direction: rtl; text-align: right;">
# این ماتریس از لحاظ ظاهری شبیه قبلی است، اما از نظر نوع داده کاملاً متفاوت است.
# در پایتون خام، ماتریس ما فقط یک «لیست» بود.
# اما اکنون یک <code>numpy.ndarray</code> داریم که:
# </p>
#
# <ul style="direction: rtl; text-align: right;">
#   <li>سرعت بسیار بیشتری در محاسبات دارد</li>
#   <li>در حافظه به‌صورت پیوسته ذخیره می‌شود</li>
#   <li>و توابع آمادهٔ زیادی برایش وجود دارد؛ مانند:</li>
#   <ul>
#     <li>ماتریس همانی</li>
#     <li>دترمینان</li>
#     <li>ترانهاده</li>
#     <li>ضرب ماتریسی</li>
#     <li>و ده‌ها عملیات دیگر</li>
#   </ul>
# </ul>
#
# <p style="direction: rtl; text-align: right;">
# پس دیگر لازم نیست برای هر کار ساده‌ای مثل ساخت ماتریس همانی یا نوشتن دترمینان، از صفر کدنویسی کنیم.
# فقط کافی است از توابع آماده‌ی NumPy درست استفاده کنیم.
# </p>
#
# <hr>
#
# <h3 style="direction: rtl; text-align: right;">مقایسه‌ی نحوهٔ چاپ ماتریس</h3>
#
# <p style="direction: rtl; text-align: right;">
# یادتان هست پایتون خام ماتریس را چطور چاپ می‌کرد؟
# </p>
#
# <pre style="
#     direction: ltr;
#     text-align: left;
#     background-color: #3a3a3a;
#     color: #e4e4e4;
#     padding: 8px;
#     border-radius: 6px;
#     font-family: monospace;
# ">
# [[1, 2, 3], [4, 5, 6]]
# </pre>
#
# <p style="direction: rtl; text-align: right;">
# این بیشتر شبیه ساختار لیست‌ها بود.
# اما اکنون NumPy چه خروجی می‌دهد؟
# </p>
#
# <pre style="
#     direction: ltr;
#     text-align: left;
#     background-color: #3a3a3a;
#     color: #e4e4e4;
#     padding: 8px;
#     border-radius: 6px;
#     font-family: monospace;
#     margin: 0 auto;
# ">
# [[1 2 3]
#  [4 5 6]]
# </pre>
#
# <p style="direction: rtl; text-align: right;">
# اگر کمی به آن نگاه کنیم، انگار پرانتز خارجی برداشته شده و هر سطر در یک خط آمده است:
# </p>
#
# <pre style="
#     direction: ltr;
#     text-align: left;
#     background-color: #3a3a3a;
#     color: #e4e4e4;
#     padding: 8px;
#     border-radius: 6px;
#     font-family: monospace;
#     margin: 0 auto;
# ">
# [1 2 3]
# [4 5 6]
# </pre>
#
# <p style="direction: rtl; text-align: right;">
# عجب!
# <strong>این دقیقاً شبیه ماتریسی‌ست که روی کاغذ می‌نویسیم! 😊</strong>
# </p>

# %% [markdown]
# <div dir ="rtl">
# بیاین این مثال رو با هم کد نویسی کنیم:
#
# <div align = "center">
#
# ![image.png](attachment:image.png)
# <div>
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### الگوریتم ساخت ماتریس \( A \) با فرمول زیر
# </div>
#
# $$
# a_{ij} = \frac{i + j}{2}
# $$
#
# <div dir="rtl">
# برای ساخت ماتریس کافی است مراحل زیر را انجام دهیم:
# </div>
# <div dir="rtl">
#
# 1. یک ماتریس خالی با ابعاد 2x3 بسازید.
# 2. یک حلقه برای سطرها اجرا کنید (i از 1 تا 2).
# 3. داخل آن یک حلقه برای ستون‌ها اجرا کنید (j از 1 تا 3).
# 4. مقدار هر درایه را با فرمول زیر حساب کنید:
# </div>
#
# $$
# a_{ij} = \frac{i + j}{2}
# $$
#
# <div dir="rtl">
#
# 5. مقدار به‌دست‌آمده را در محل مناسب ماتریس قرار دهید.
# 6. پس از پایان حلقه‌ها، ماتریس نهایی کامل خواهد شد و می‌توان آن را چاپ کرد.
#
# </div>

# %%
import numpy as np

# ابعاد ماتریس
rows = 2
cols = 3

# ساخت ماتریس خالی با ابعاد 3×2
A = np.zeros((rows, cols))

# پر کردن ماتریس بر اساس فرمول a_ij = (i+j)/2
for i in range(rows):         # i = 0,1
    for j in range(cols):     # j = 0,1,2
        A[i, j] = (i+1 + (j+1)) / 2   # +1 چون اندیس‌گذاری پایتون از 0 شروع می‌شود

print("matrix A:")
print(A)
# Out:
# matrix A:
# [[1.  1.5 2. ]
#  [1.5 2.  2.5]]
